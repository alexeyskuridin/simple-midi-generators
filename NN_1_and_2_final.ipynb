# %%
#загрузка библиотек и создание функций

import pretty_midi as pm
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from tensorflow.keras.callbacks import ModelCheckpoint

from scipy.io import wavfile

#from keras.models import Sequential
#from keras.layers import Dense, Dropout, LSTM
#from keras.utils import np_utils
#from keras.callbacks import ModelCheckpoint

def midi_to_list(midi):
    pitch_list = []
    for note in midi.instruments[0].notes:
        pitch_list.append(note.pitch)
    return pitch_list

def list_shift(pitch_list, lowest, highest):
    pitch_list_new = []
    for note in pitch_list:
        if(note > highest):
            print('note with pitch ' + str(note) + 'spotted')
        pitch_list_new.append(note - lowest)
    return pitch_list_new

notes_4_first_opt = {0: 0, 2: 1, 3:2, 5:3, 7:4, 8:5, 10:6, 12:7}

def first_opt(pitch_list_new):
    tmp = []
    for note in pitch_list_new:
        tmp.append(notes_4_first_opt[note])
    return tmp

to_pitch_dict = {0: 0, 1: 2, 2:3, 3:5, 4:7, 5:8, 6:10, 7:12}


def to_pitch(final_midi):
    tmp = []
    for note in final_midi:
        tmp.append(to_pitch_dict[note])
    return tmp

def shift_back(final_midi, lowest):
    tmp = []
    for note in final_midi:
        tmp.append(note + lowest)
    return tmp

import soundfile

import pyfluidsynth
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-657ba12e4d0a> in <module>
#      55 import soundfile
#      56
# ---> 57 import pyfluidsynth
#
# ModuleNotFoundError: No module named 'pyfluidsynth'

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in d:\programms\anaconda\lib\site-packages (1.3.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (3.11.4)
# Requirement already satisfied: pandas>=0.21.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: attrs in d:\programms\anaconda\lib\site-packages (from streamlit) (19.3.0)
# Requirement already satisfied: astor in d:\programms\anaconda\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: numpy in d:\programms\anaconda\lib\site-packages (from streamlit) (1.18.1)
# Requirement already satisfied: base58 in d:\programms\anaconda\lib\site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: blinker in d:\programms\anaconda\lib\site-packages (from streamlit) (1.4)
# Requirement already satisfied: requests in d:\programms\anaconda\lib\site-packages (from streamlit) (2.22.0)
# Requirement already satisfied: pympler>=0.9 in d:\programms\anaconda\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: altair>=3.2.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: gitpython!=3.1.19 in d:\programms\anaconda\lib\site-packages (from streamlit) (3.1.26)
# Requirement already satisfied: pillow>=6.2.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (7.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in d:\programms\anaconda\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: python-dateutil in d:\programms\anaconda\lib\site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: validators in d:\programms\anaconda\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: tzlocal in d:\programms\anaconda\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: click<8.0,>=7.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (7.0)
# Requirement already satisfied: tornado>=5.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (6.0.3)
# Requirement already satisfied: toml in d:\programms\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pyarrow in d:\programms\anaconda\lib\site-packages (from streamlit) (6.0.1)
# Requirement already satisfied: packaging in d:\programms\anaconda\lib\site-packages (from streamlit) (20.1)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in d:\programms\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (4.1.0)
# Requirement already satisfied: six>=1.9 in d:\programms\anaconda\lib\site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (1.14.0)
# Requirement already satisfied: setuptools in d:\programms\anaconda\lib\site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (45.2.0.post20200210)
# Requirement already satisfied: pytz>=2017.2 in d:\programms\anaconda\lib\site-packages (from pandas>=0.21.0->streamlit) (2019.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: entrypoints in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: toolz in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (0.10.0)
# Requirement already satisfied: jsonschema>=3.0 in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: jinja2 in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3; python_version < "3.8" in d:\programms\anaconda\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\programms\anaconda\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: traitlets>=4.3.2 in d:\programms\anaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (4.3.3)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in d:\programms\anaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in d:\programms\anaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: decorator>=3.4.0 in d:\programms\anaconda\lib\site-packages (from validators->streamlit) (4.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programms\anaconda\lib\site-packages (from packaging->streamlit) (2.4.6)
# Requirement already satisfied: pathtools>=0.1.1 in d:\programms\anaconda\lib\site-packages (from watchdog; platform_system != "Darwin"->streamlit) (0.1.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in d:\programms\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\programms\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.15.7)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programms\anaconda\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\programms\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: ipython-genutils in d:\programms\anaconda\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyter-client in d:\programms\anaconda\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipython>=5.0.0 in d:\programms\anaconda\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (7.12.0)
# Requirement already satisfied: nbformat>=4.2.0 in d:\programms\anaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\programms\anaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: zipp>=0.5 in d:\programms\anaconda\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0->altair>=3.2.0->streamlit) (2.2.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in d:\programms\anaconda\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\programms\anaconda\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.6.1)
# Requirement already satisfied: pyzmq>=13 in d:\programms\anaconda\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (18.1.1)
# Requirement already satisfied: jedi>=0.10 in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (3.0.3)
# Requirement already satisfied: pygments in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.5.2)
# Requirement already satisfied: backcall in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.0)
# Requirement already satisfied: pickleshare in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.4.3)
# Requirement already satisfied: notebook>=4.4.1 in d:\programms\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.3)
# Requirement already satisfied: parso>=0.5.0 in d:\programms\anaconda\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.5.2)
# Requirement already satisfied: wcwidth in d:\programms\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.8)
# Requirement already satisfied: Send2Trash in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: nbconvert in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: prometheus-client in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: bleach in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.1.0)
# Requirement already satisfied: defusedxml in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: testpath in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: webencodings in d:\programms\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)

# %%
import fluidsynth

# %%
#создание нейросети 1 и загрузка весов 1

model_1 = Sequential()
model_1.add(LSTM(512, input_shape=(5, 8), return_sequences=True))
model_1.add(Dropout(0.2))
model_1.add(LSTM(256, return_sequences=True))
model_1.add(Dropout(0.2))
model_1.add(LSTM(128))
model_1.add(Dropout(0.2))
model_1.add(Dense(8, activation='softmax'))

filename = "model_1_weights_saved.hdf5" 
model_1.load_weights(filename) 
model_1.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
#создание нейросети 2 и загрузка весов 2

model_2 = Sequential()
model_2.add(LSTM(512, input_shape=(5, 14), return_sequences=True))
model_2.add(Dropout(0.2))
model_2.add(LSTM(256, return_sequences=True))
model_2.add(Dropout(0.2))
model_2.add(LSTM(128))
model_2.add(Dropout(0.2))
model_2.add(Dense(14, activation='softmax'))

filename = "model_2_weights_saved.hdf5" 
model_2.load_weights(filename) 
model_2.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
#генерация мелодии 1

melody_pred = np.zeros((5))
X_pred = np.zeros((1,5,8))

melody_pred[0] = int(np.round(7*np.random.rand()))
melody_pred[1] = int(np.round(7*np.random.rand()))
melody_pred[2] = int(np.round(7*np.random.rand()))
melody_pred[3] = int(np.round(7*np.random.rand()))
melody_pred[4] = int(np.round(7*np.random.rand()))

for i in range(melody_pred.shape[0]):
    X_pred[0][i][int(melody_pred[i])] = 1
    
X_pred_012 = X_pred

final_midi = []
zeros = np.zeros((8))
for i in range(0,19):
    prediction = np.argmax(model_1.predict(X_pred, verbose = 0))
    
    final_midi.append(prediction)
    X_pred[0][0] = X_pred[0][1]
    X_pred[0][1] = X_pred[0][2]
    X_pred[0][2] = X_pred[0][3]
    X_pred[0][3] = X_pred[0][4]
    X_pred[0][4] = zeros
    X_pred[0][4][prediction] = 1

melody_start = []
for note in melody_pred:
    melody_start.append(int(note))
final_midi = melody_start + final_midi

final_shifted = shift_back(to_pitch(final_midi), 69)

export_midi = pm.PrettyMIDI('Dataset/1.mid')

for i in range(24):
    export_midi.instruments[0].notes[i].pitch = final_shifted[i]

export_midi.write('Output_1.mid')

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.3.1-py2.py3-none-any.whl (9.2 MB)
# Requirement already satisfied: python-dateutil in d:\programms\anaconda\lib\site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: pandas>=0.21.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: tzlocal in d:\programms\anaconda\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: attrs in d:\programms\anaconda\lib\site-packages (from streamlit) (19.3.0)
# Requirement already satisfied: requests in d:\programms\anaconda\lib\site-packages (from streamlit) (2.22.0)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in d:\programms\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: astor in d:\programms\anaconda\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (3.11.4)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in d:\programms\anaconda\lib\site-packages (from streamlit) (1.18.1)
# Requirement already satisfied: cachetools>=4.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (4.1.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: packaging in d:\programms\anaconda\lib\site-packages (from streamlit) (20.1)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp37-cp37m-win_amd64.whl (15.4 MB)
# Requirement already satisfied: click<8.0,>=7.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (7.0)
# Requirement already satisfied: tornado>=5.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (6.0.3)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: pillow>=6.2.0 in d:\programms\anaconda\lib\site-packages (from streamlit) (7.0.0)
# Requirement already satisfied: six>=1.5 in d:\programms\anaconda\lib\site-packages (from python-dateutil->streamlit) (1.14.0)
# Requirement already satisfied: pytz>=2017.2 in d:\programms\anaconda\lib\site-packages (from pandas>=0.21.0->streamlit) (2019.3)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\programms\anaconda\lib\site-packages (from requests->streamlit) (1.25.8)
# Requirement already satisfied: pathtools>=0.1.1 in d:\programms\anaconda\lib\site-packages (from watchdog; platform_system != "Darwin"->streamlit) (0.1.2)
# Requirement already satisfied: setuptools in d:\programms\anaconda\lib\site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (45.2.0.post20200210)
# Requirement already satisfied: jsonschema>=3.0 in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: toolz in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (0.10.0)
# Requirement already satisfied: jinja2 in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.1)
# Requirement already satisfied: entrypoints in d:\programms\anaconda\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: decorator>=3.4.0 in d:\programms\anaconda\lib\site-packages (from validators->streamlit) (4.4.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in d:\programms\anaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in d:\programms\anaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.2 in d:\programms\anaconda\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (4.3.3)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programms\anaconda\lib\site-packages (from packaging->streamlit) (2.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting typing-extensions>=3.7.4.3; python_version < "3.8"
#   Downloading typing_extensions-4.0.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\programms\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in d:\programms\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programms\anaconda\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: ipython>=5.0.0 in d:\programms\anaconda\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (7.12.0)
# Requirement already satisfied: jupyter-client in d:\programms\anaconda\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in d:\programms\anaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\programms\anaconda\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: ipython-genutils in d:\programms\anaconda\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in d:\programms\anaconda\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0->altair>=3.2.0->streamlit) (2.2.0)
# Requirement already satisfied: backcall in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.4.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: pygments in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.5.2)
# Requirement already satisfied: pickleshare in d:\programms\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\programms\anaconda\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.6.1)
# Requirement already satisfied: pyzmq>=13 in d:\programms\anaconda\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (18.1.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in d:\programms\anaconda\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: notebook>=4.4.1 in d:\programms\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.3)
# Requirement already satisfied: wcwidth in d:\programms\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.8)
# Requirement already satisfied: parso>=0.5.0 in d:\programms\anaconda\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.5.2)
# Requirement already satisfied: prometheus-client in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: nbconvert in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: Send2Trash in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in d:\programms\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: defusedxml in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: bleach in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.1.0)
# Requirement already satisfied: testpath in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\programms\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: webencodings in d:\programms\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13455 sha256=2e67a4a3a8fbfd5deeee370847ab047513c6c168576147ea53815ad487b7228b
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\22\f5\18\df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built blinker
# Installing collected packages: pympler, altair, toml, validators, pydeck, smmap, gitdb, typing-extensions, gitpython, pyarrow, blinker, base58, streamlit
# Successfully installed altair-4.2.0 base58-2.1.1 blinker-1.4 gitdb-4.0.9 gitpython-3.1.26 pyarrow-6.0.1 pydeck-0.7.1 pympler-1.0.1 smmap-5.0.0 streamlit-1.3.1 toml-0.10.2 typing-extensions-4.0.1 validators-0.18.2

# %%
# !pip install pyfluidsynth
# Out:
# Collecting pyfluidsynth
#   Downloading pyFluidSynth-1.3.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy in d:\programms\anaconda\lib\site-packages (from pyfluidsynth) (1.18.1)
# Installing collected packages: pyfluidsynth
# Successfully installed pyfluidsynth-1.3.0

# %%
# !pip install soundfile
# Out:
# Collecting soundfile
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Requirement already satisfied: cffi>=1.0 in d:\programms\anaconda\lib\site-packages (from soundfile) (1.14.0)
# Requirement already satisfied: pycparser in d:\programms\anaconda\lib\site-packages (from cffi>=1.0->soundfile) (2.19)
# Installing collected packages: soundfile
# Successfully installed soundfile-0.10.3.post1

# %%
#генерация мелодии 2

melody_pred = np.zeros((5))
X_pred = np.zeros((1,5,14))

melody_pred[0] = int(np.round(13*np.random.rand()))
melody_pred[1] = int(np.round(13*np.random.rand()))
melody_pred[2] = int(np.round(13*np.random.rand()))
melody_pred[3] = int(np.round(13*np.random.rand()))
melody_pred[4] = int(np.round(13*np.random.rand()))

for i in range(melody_pred.shape[0]):
    X_pred[0][i][int(melody_pred[i])] = 1
    
X_pred_012 = X_pred

final_midi = []
zeros = np.zeros((14))
for i in range(0,19):
    prediction = np.argmax(model_2.predict(X_pred, verbose = 0))
    
    final_midi.append(prediction)
    X_pred[0][0] = X_pred[0][1]
    X_pred[0][1] = X_pred[0][2]
    X_pred[0][2] = X_pred[0][3]
    X_pred[0][3] = X_pred[0][4]
    X_pred[0][4] = zeros
    X_pred[0][4][prediction] = 1

final_midi
melody_start = []
for note in melody_pred:
    melody_start.append(int(note))
final_midi = melody_start + final_midi

final_shifted = shift_back(final_midi, 69)

export_midi = pm.PrettyMIDI('Dataset/1.mid')

for i in range(24):
    export_midi.instruments[0].notes[i].pitch = final_shifted[i]

export_midi.write('Output_2.mid')
wav_2 = export_midi.synthesize()

# %%
fs = 49301
signal_1 = np.int16(wav_1)
wavfile.write('Output_1.wav', fs, signal_1)

signal_2 = np.int16(wav_2)
wavfile.write('Output_2.wav', fs, signal_2)

# %%
# Out:
# 49301.46666666667
